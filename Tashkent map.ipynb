# %%
import leafmap.kepler as leafmap
import pandas as pd 
import numpy as np
import base64

# %%
m = leafmap.Map(center=[37.7621, -122.4143], zoom=12)

#csv_data = "C:/Users/Nikita.Dronov/OneDrive - Cushman & Wakefield/Desktop/Tashkent/dev/DATA TASHKENT GEO (1).csv"
#config_data = 'C:/Users/Nikita.Dronov/OneDrive - Cushman & Wakefield/Desktop/Tashkent/dev/out.json'
dataLink = "https://1drv.ms/x/s!AuM2Z_gMxN6KhuFxTGeBN3aVt_cE6Q?e=0vIZGG"
configLink = "https://1drv.ms/u/s!AuM2Z_gMxN6KhvIGsuLhjpLsbAnyZw?e=hwGmMj"

# %%
def create_onedrive_directdownload (onedrive_link):
    data_bytes64 = base64.b64encode(bytes(onedrive_link, 'utf-8'))
    data_bytes64_String = data_bytes64.decode('utf-8').replace('/','_').replace('+','-').rstrip("=")
    resultUrl = f"https://api.onedrive.com/v1.0/shares/u!{data_bytes64_String}/root/content"
    return resultUrl

dirLink = create_onedrive_directdownload(dataLink)
config_data = create_onedrive_directdownload(configLink)

# %%
#let's download a df and split it into 3 separate dfs
df0 = pd.read_excel(dirLink, sheet_name="to_csv")
#df0 = pd.read_csv(csv_data, sep=';')

df_office = df0.loc[df0["Тип данных"]=="БЦ"]
df_mall = df0.loc[df0["Тип данных"]=="ТЦ"]
df_bazaar = df0.loc[df0["Тип данных"]=="bazar"]

# %%
'''
import os  
os.makedirs('../dfs/', exist_ok=True)  

df_office.to_csv('../dfs/df_office.to_csv')
df_mall.to_csv('../dfs/df_mall.to_csv')
df_bazaar.to_csv('../dfs/df_bazaar.to_csv')
'''
# Out:
# "\nimport os  \nos.makedirs('../dfs/', exist_ok=True)  \n\ndf_office.to_csv('../dfs/df_office.to_csv')\ndf_mall.to_csv('../dfs/df_mall.to_csv')\ndf_bazaar.to_csv('../dfs/df_bazaar.to_csv')\n"

# %%
df_bazaar
# Out:
#        ID  Название проекта                 Адрес                  Район  \
# 50   1051       Alay вazaar  улица Истикбол, 45-1     Юнусабадский район
# 104  7002  Yangioвod вazaar                   NaN      Яшнабадский район
# 105  7003    Qo'yliq вazaar                   NaN     Бектимирский район
# 106  7004    Miraвad вazaar                   NaN      Мирабадский район
# 107  7005    Farkhad вazaar                   NaN      Учтепинский район
# 108  7006     Chorsu вazaar                   NaN  Шайхонтохурский район
#
#                 District  latitude  longitude Класс old Класс  \
# 50      Yunusobod Tumani  41.31930   69.28315         А     А
# 104     Yashnobod Tumani  41.25902   69.35306       NaN   NaN
# 105      Bektemir Tumani  41.23652   69.32958       NaN   NaN
# 106       Mirobod Tumani  41.29100   69.27480       NaN   NaN
# 107       Uchtepa Tumani  41.28553   69.18981       NaN   NaN
# 108  Shayhontohur Tumani  41.32676   69.23501       NaN   NaN
#
#      Дата строительства  ...  Арендуемая площадь  Доля вакантных площадей  \
# 50               2020.0  ...              7310.0                      NaN
# 104                 NaN  ...                 NaN                      NaN
# 105                 NaN  ...                 NaN                      NaN
# 106                 NaN  ...                 NaN                      NaN
# 107                 NaN  ...                 NaN                      NaN
# 108                 NaN  ...                 NaN                      NaN
#
#     Количество этажей Ставка аренды      Статус Тип данных Коммент  \
# 50                NaN           NaN  Нет данных      bazar     NaN
# 104               NaN           NaN         NaN      bazar     NaN
# 105               NaN           NaN         NaN      bazar     NaN
# 106               NaN           NaN         NaN      bazar     NaN
# 107               NaN           NaN         NaN      bazar     NaN
# 108               NaN           NaN         NaN      bazar     NaN
#
#     Service field 1  Service field 2  Service field 3
# 50              NaN              NaN              NaN
# 104             NaN              NaN              NaN
# 105             NaN              NaN              NaN
# 106             NaN              NaN              NaN
# 107             NaN              NaN              NaN
# 108             NaN              NaN              NaN
#
# [6 rows x 21 columns]

# %%
#create and display the map
m.add_df(df_office, layer_name="Office", config=config_data)
m.add_data(df_bazaar, name="bazaar")
m.add_data(df_mall, name="mall")
m
# Out:
# Map(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'cf6ebl3h', 'type': 'poi…

# %%
#save the adjustments to the config
m.config
m.save_config ('./out.json')

#create an html file
m.to_html("../html/TASHKENT.html")
